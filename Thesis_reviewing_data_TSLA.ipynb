# 34  2023-02-01  4:00:00.047886148  K  172.15       8  172.99       1       R
# 35  2023-02-01  4:00:00.048812286  K  172.15       8  172.99       1       R
# 36  2023-02-01  4:00:00.051130642  K  172.15       8  172.99       1       R
# 37  2023-02-01  4:00:00.051145988  K  172.15       8  172.99       1       R
# 38  2023-02-01  4:00:00.051182168  K  172.15       8  172.99       1       R
# 39  2023-02-01  4:00:00.063133353  K  172.15       7  172.99       1       R
# 40  2023-02-01  4:00:00.065603756  K  172.15       7  172.99       1       R
# 41  2023-02-01  4:00:00.067093880  K  172.15       7  172.99       1       R
# 42  2023-02-01  4:00:00.068389553  K  172.15       7  172.99       1       R
# 43  2023-02-01  4:00:00.068960135  K  172.15       7  172.99       1       R
# 44  2023-02-01  4:00:00.069000862  K  172.15       7  172.99       1       R
# 45  2023-02-01  4:00:00.069141778  K  172.15       7  172.99       1       R
# 46  2023-02-01  4:00:00.069549246  K  172.15       7  172.99       1       R
# 47  2023-02-01  4:00:00.069608648  K  172.15       7  172.99       1       R
# 48  2023-02-01  4:00:00.069749624  K  172.15       7  172.99       1       R
# 49  2023-02-01  4:00:00.070393553  K  172.15       7  172.99       1       R
#
#     QU_SEQNUM  NATBBO_IND  QU_CANCEL QU_SOURCE SYM_ROOT  SYM_SUFFIX
# 0         953           1        NaN         N     TSLA         NaN
# 1        2067           1        NaN         N     TSLA         NaN
# 2        3525           2        NaN         N     TSLA         NaN
# 3        3544           4        NaN         N     TSLA         NaN
# 4        4543           0        NaN         N     TSLA         NaN
# 5        4544           0        NaN         N     TSLA         NaN
# 6        4545           0        NaN         N     TSLA         NaN
# 7        4549           0        NaN         N     TSLA         NaN
# 8        4551           0        NaN         N     TSLA         NaN
# 9        4562           0        NaN         N     TSLA         NaN
# 10       4576           0        NaN         N     TSLA         NaN
# 11       4639           2        NaN         N     TSLA         NaN
# 12       4658           0        NaN         N     TSLA         NaN
# 13       4660           0        NaN         N     TSLA         NaN
# 14       4668           2        NaN         N     TSLA         NaN
# 15       4705           2        NaN         N     TSLA         NaN
# 16       4713           0        NaN         N     TSLA         NaN
# 17       5578           2        NaN         N     TSLA         NaN
# 18       5665           0        NaN         N     TSLA         NaN
# 19       5666           0        NaN         N     TSLA         NaN
# 20       5667           0        NaN         N     TSLA         NaN
# 21       5668           0        NaN         N     TSLA         NaN
# 22       5669           0        NaN         N     TSLA         NaN
# 23       5670           0        NaN         N     TSLA         NaN
# 24       5671           0        NaN         N     TSLA         NaN
# 25       5672           0        NaN         N     TSLA         NaN
# 26       5673           0        NaN         N     TSLA         NaN
# 27       5674           0        NaN         N     TSLA         NaN
# 28       5676           2        NaN         N     TSLA         NaN
# 29       5677           0        NaN         N     TSLA         NaN
# 30       5678           0        NaN         N     TSLA         NaN
# 31       5679           2        NaN         N     TSLA         NaN
# 32       5680           0        NaN         N     TSLA         NaN
# 33       5681           0        NaN         N     TSLA         NaN
# 34       5686           0        NaN         N     TSLA         NaN
# 35       5688           0        NaN         N     TSLA         NaN
# 36       5690           0        NaN         N     TSLA         NaN
# 37       5691           0        NaN         N     TSLA         NaN
# 38       5692           0        NaN         N     TSLA         NaN
# 39       5745           0        NaN         N     TSLA         NaN
# 40       5759           0        NaN         N     TSLA         NaN
# 41       5761           0        NaN         N     TSLA         NaN
# 42       5764           0        NaN         N     TSLA         NaN
# 43       5768           0        NaN         N     TSLA         NaN
# 44       5769           0        NaN         N     TSLA         NaN
# 45       5770           0        NaN         N     TSLA         NaN
# 46       5771           0        NaN         N     TSLA         NaN
# 47       5772           0        NaN         N     TSLA         NaN
# 48       5773           0        NaN         N     TSLA         NaN
# 49       5777           0        NaN         N     TSLA         NaN

# %%
#Number of columns
# num_columns = len(df.columns)
# print(f"Number of columns: {num_columns}")
# #List of names 
# column_titles = df.columns.tolist()
# print("Column titles:", column_titles)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        10000 non-null  object
#  1   TIME_M      10000 non-null  object
#  2   EX          10000 non-null  object
#  3   BID         10000 non-null  float64
#  4   BIDSIZ      10000 non-null  int64
#  5   ASK         10000 non-null  float64
#  6   ASKSIZ      10000 non-null  int64
#  7   QU_COND     10000 non-null  object
#  8   QU_SEQNUM   10000 non-null  int64
#  9   NATBBO_IND  10000 non-null  int64
#  10  QU_CANCEL   0 non-null      float64
#  11  QU_SOURCE   10000 non-null  object
#  12  SYM_ROOT    10000 non-null  object
#  13  SYM_SUFFIX  0 non-null      float64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe()
# Out:
#                 BID        BIDSIZ           ASK        ASKSIZ      QU_SEQNUM  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean     173.200513      2.773700    173.365946      2.525500  161351.407300
# std        3.618280      5.225535      5.779378      3.990356  118852.508218
# min        0.000000      0.000000      0.000000      0.000000     953.000000
# 25%      173.090000      1.000000    173.370000      1.000000   43232.000000
# 50%      173.280000      1.000000    173.500000      1.000000  146837.000000
# 75%      173.520000      2.000000    173.790000      2.000000  291588.250000
# max      174.140000     75.000000    199.000000     65.000000  346480.000000
#
#          NATBBO_IND  QU_CANCEL  SYM_SUFFIX
# count  10000.000000        0.0         0.0
# mean       0.929600        NaN         NaN
# std        1.312332        NaN         NaN
# min        0.000000        NaN         NaN
# 25%        0.000000        NaN         NaN
# 50%        0.000000        NaN         NaN
# 75%        2.000000        NaN         NaN
# max        4.000000        NaN         NaN
