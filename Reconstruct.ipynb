# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from scipy.spatial.distance import cdist
import numpy as np
import os

import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score
from sklearn.preprocessing import MinMaxScaler

import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook'

mixed_playlist = pd.read_csv('data/mixed_playlist.csv')

# %%
# To display categories "Users" that exists in the column user
num_categories = mixed_playlist.user.unique()

# %%
mapping = {'unknown': 0, 'delta': 1, 'gamma': 2, 'alpha': 3, 'dzeta': 4, 'beta': 5, 'epsilon': 6}
mixed_playlist['user'] = mixed_playlist['user'].replace(mapping)
mixed_playlist.user
# Out:
# 0       0
# 1       1
# 2       2
# 3       2
# 4       3
#        ..
# 3894    5
# 3895    1
# 3896    4
# 3897    5
# 3898    0
# Name: user, Length: 3899, dtype: int64

# %%
# Replace 'unknown' values in 'top_year' column with 0
mixed_playlist['top_year'] = mixed_playlist['top_year'].replace('unknown', 0)

mixed_playlist.top_year
# Out:
# 0          0
# 1       2022
# 2       2020
# 3       2018
# 4       2020
#         ...
# 3894    2020
# 3895    2020
# 3896    2021
# 3897    2018
# 3898       0
# Name: top_year, Length: 3899, dtype: object

# %%
mixed_playlist.info()
mixed_playlist.dropna(inplace=True)

# display the descriptive statistics of numeric variables
mixed_playlist.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3899 entries, 0 to 3898
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3890 non-null   object
#  1   album             3890 non-null   object
#  2   artist            3899 non-null   object
#  3   release_date      3899 non-null   object
#  4   length            3899 non-null   int64
#  5   popularity        3899 non-null   int64
#  6   acousticness      3899 non-null   float64
#  7   danceability      3899 non-null   float64
#  8   energy            3899 non-null   float64
#  9   instrumentalness  3899 non-null   float64
#  10  liveness          3899 non-null   float64
#  11  loudness          3899 non-null   float64
#  12  speechiness       3899 non-null   float64
#  13  tempo             3899 non-null   float64
#  14  valence           3899 non-null   float64
#  15  time_signature    3899 non-null   int64
#  16  key               3899 non-null   int64
#  17  mode              3899 non-null   int64
#  18  uri               3899 non-null   object
#  19  release_year      3899 non-null   int64
#  20  top_year          3899 non-null   object
#  21  user              3899 non-null   int64
# dtypes: float64(9), int64(7), object(6)
# memory usage: 670.3+ KB
#              length   popularity  acousticness  danceability       energy  \
# count  3.890000e+03  3890.000000   3890.000000   3890.000000  3890.000000
# mean   2.444187e+05    32.005398      0.425120      0.554521     0.523066
# std    1.045747e+05    24.920088      0.363021      0.192029     0.265409
# min    3.105300e+04     0.000000      0.000001      0.000000     0.000545
# 25%    1.880332e+05     1.000000      0.058025      0.424250     0.313000
# 50%    2.242485e+05    34.000000      0.339000      0.575000     0.547500
# 75%    2.744900e+05    51.000000      0.793000      0.701000     0.738750
# max    1.921683e+06    91.000000      0.996000      0.971000     0.995000
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       3890.000000  3890.000000  3890.000000  3890.000000  3890.000000
# mean           0.296768     0.167134   -10.436968     0.085179   115.826347
# std            0.386456     0.143656     6.209512     0.092698    28.662454
# min            0.000000     0.017900   -42.117000     0.000000     0.000000
# 25%            0.000004     0.094500   -12.790000     0.036800    94.546750
# 50%            0.005730     0.112000    -8.589000     0.047000   115.151500
# 75%            0.773000     0.172000    -6.222500     0.086775   131.986750
# max            0.995000     0.991000     0.532000     0.952000   209.596000
#
#            valence  time_signature          key         mode  release_year  \
# count  3890.000000     3890.000000  3890.000000  3890.000000   3890.000000
# mean      0.384641        3.873779     5.295630     0.466838   2012.748072
# std       0.254691        0.465588     3.507038     0.498963     10.418784
# min       0.000000        0.000000     0.000000     0.000000   1957.000000
# 25%       0.161000        4.000000     2.000000     0.000000   2012.000000
# 50%       0.355000        4.000000     5.000000     0.000000   2016.000000
# 75%       0.572000        4.000000     8.000000     1.000000   2018.000000
# max       0.981000        5.000000    11.000000     1.000000   2022.000000
#
#               user
# count  3890.000000
# mean      3.357326
# std       1.844656
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max       6.000000

# %%
# mixed_playlist

# %%
# display the correlation matrix between numeric variables
corr = mixed_playlist.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_3c99d_row0_col0, #T_3c99d_row1_col1, #T_3c99d_row2_col2, #T_3c99d_row3_col3, #T_3c99d_row4_col4, #T_3c99d_row5_col5, #T_3c99d_row6_col6, #T_3c99d_row7_col7, #T_3c99d_row8_col8, #T_3c99d_row9_col9, #T_3c99d_row10_col10, #T_3c99d_row11_col11, #T_3c99d_row12_col12, #T_3c99d_row13_col13, #T_3c99d_row14_col14, #T_3c99d_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col1, #T_3c99d_row3_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_3c99d_row0_col3, #T_3c99d_row7_col15, #T_3c99d_row12_col14 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col4, #T_3c99d_row12_col7, #T_3c99d_row13_col4 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_3c99d_row0_col5, #T_3c99d_row15_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_3c99d_row0_col6, #T_3c99d_row2_col10, #T_3c99d_row8_col13, #T_3c99d_row11_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col7, #T_3c99d_row14_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_3c99d_row0_col8, #T_3c99d_row1_col9, #T_3c99d_row1_col14, #T_3c99d_row11_col15, #T_3c99d_row13_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col9, #T_3c99d_row6_col0, #T_3c99d_row9_col15, #T_3c99d_row10_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col10, #T_3c99d_row8_col1, #T_3c99d_row14_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col11, #T_3c99d_row15_col13 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col12, #T_3c99d_row11_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col13, #T_3c99d_row4_col0, #T_3c99d_row6_col14, #T_3c99d_row8_col12, #T_3c99d_row9_col12, #T_3c99d_row12_col0, #T_3c99d_row15_col12 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col14 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3c99d_row0_col15, #T_3c99d_row4_col5, #T_3c99d_row9_col6, #T_3c99d_row11_col12, #T_3c99d_row11_col13 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col0, #T_3c99d_row14_col6, #T_3c99d_row14_col13 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_3c99d_row1_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_3c99d_row1_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_3c99d_row1_col5, #T_3c99d_row7_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col6, #T_3c99d_row3_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col7, #T_3c99d_row6_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3c99d_row1_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_3c99d_row1_col10, #T_3c99d_row7_col9, #T_3c99d_row12_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_3c99d_row1_col11, #T_3c99d_row4_col12, #T_3c99d_row5_col14, #T_3c99d_row6_col11, #T_3c99d_row12_col9 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col12, #T_3c99d_row5_col13, #T_3c99d_row6_col13, #T_3c99d_row14_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col13, #T_3c99d_row7_col13, #T_3c99d_row12_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_3c99d_row1_col15, #T_3c99d_row10_col15 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_3c99d_row2_col0, #T_3c99d_row3_col1, #T_3c99d_row15_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3c99d_row2_col1, #T_3c99d_row2_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_3c99d_row2_col3, #T_3c99d_row2_col4, #T_3c99d_row2_col6, #T_3c99d_row2_col7, #T_3c99d_row2_col9, #T_3c99d_row2_col11, #T_3c99d_row2_col14, #T_3c99d_row2_col15, #T_3c99d_row4_col2, #T_3c99d_row5_col1, #T_3c99d_row5_col8, #T_3c99d_row5_col10, #T_3c99d_row7_col5, #T_3c99d_row10_col0, #T_3c99d_row10_col5, #T_3c99d_row12_col13, #T_3c99d_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3c99d_row2_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_3c99d_row2_col8, #T_3c99d_row9_col13, #T_3c99d_row15_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_3c99d_row2_col13, #T_3c99d_row3_col6, #T_3c99d_row3_col13, #T_3c99d_row8_col5, #T_3c99d_row12_col6, #T_3c99d_row13_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_3c99d_row3_col2, #T_3c99d_row3_col9, #T_3c99d_row6_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_3c99d_row3_col4, #T_3c99d_row10_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_3c99d_row3_col7, #T_3c99d_row3_col10 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_3c99d_row3_col8, #T_3c99d_row10_col8, #T_3c99d_row13_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_3c99d_row3_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_3c99d_row3_col12, #T_3c99d_row10_col1, #T_3c99d_row11_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_3c99d_row3_col14, #T_3c99d_row9_col5, #T_3c99d_row13_col3, #T_3c99d_row14_col10 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_3c99d_row3_col15 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_3c99d_row4_col1, #T_3c99d_row7_col12, #T_3c99d_row12_col15 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3c99d_row4_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_3c99d_row4_col6, #T_3c99d_row4_col15 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_3c99d_row4_col7 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_3c99d_row4_col8 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_3c99d_row4_col9, #T_3c99d_row4_col14, #T_3c99d_row14_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_3c99d_row4_col10 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_3c99d_row4_col11, #T_3c99d_row6_col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_3c99d_row4_col13, #T_3c99d_row7_col0, #T_3c99d_row13_col1, #T_3c99d_row13_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_3c99d_row5_col2, #T_3c99d_row6_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_3c99d_row5_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_3c99d_row5_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col7, #T_3c99d_row9_col0, #T_3c99d_row11_col9, #T_3c99d_row15_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col9, #T_3c99d_row15_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col11, #T_3c99d_row10_col13 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col12, #T_3c99d_row13_col14 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_3c99d_row5_col15 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_3c99d_row6_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3c99d_row6_col2, #T_3c99d_row7_col11 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_3c99d_row6_col3, #T_3c99d_row14_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_3c99d_row6_col8, #T_3c99d_row10_col2, #T_3c99d_row12_col3, #T_3c99d_row13_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_3c99d_row6_col9, #T_3c99d_row7_col6, #T_3c99d_row8_col9, #T_3c99d_row9_col11, #T_3c99d_row14_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_3c99d_row6_col12, #T_3c99d_row8_col0, #T_3c99d_row9_col1, #T_3c99d_row10_col14 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_3c99d_row6_col15 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_3c99d_row7_col2, #T_3c99d_row8_col15 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3c99d_row7_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_3c99d_row7_col4 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_3c99d_row7_col8, #T_3c99d_row7_col14 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_3c99d_row7_col10 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_3c99d_row8_col2, #T_3c99d_row9_col10, #T_3c99d_row15_co

# %%
correlation_matrix = mixed_playlist.corr()
# You can set a threshold for correlation values and remove features with high correlation
threshold = 0.7  # Adjust this threshold as needed
highly_correlated_features = set()
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname = correlation_matrix.columns[i]
            highly_correlated_features.add(colname)

mixed_playlist.drop(highly_correlated_features, axis=1, inplace=True)

# %%
# mixed_playlist

# %%
# It is considered Irrelevant features every description or string that does not contribute in understanding the nature of the song
irrelevant_features = ['name', 'album', 'artist','release_date','uri']  # Modify this list with your irrelevant feature names
mixed_playlist.drop(irrelevant_features, axis=1, inplace=True)

# %%
mixed_playlist
# Out:
#       length  popularity  acousticness  danceability  instrumentalness  \
# 0      76933          53      0.996000         0.329          0.866000
# 1     172626          62      0.622000         0.615          0.000008
# 2     175269          72      0.413000         0.834          0.000040
# 3     175266           0      0.404000         0.797          0.000153
# 4     264735          53      0.061600         0.788          0.711000
# ...      ...         ...           ...           ...               ...
# 3894  324133          41      0.992000         0.529          0.922000
# 3895  185506           0      0.942000         0.417          0.001700
# 3896  352105          51      0.000016         0.467          0.908000
# 3897  154826          16      0.045300         0.589          0.008480
# 3898  229626          33      0.161000         0.724          0.004440
#
#       liveness  speechiness    tempo  valence  time_signature  key  mode  \
# 0       0.0906       0.0448   70.295    0.238               4   11     0
# 1       0.1920       0.2530   86.976    0.626               4    1     1
# 2       0.1130       0.3410   89.989    0.356               4    6     0
# 3       0.2550       0.0327  128.027    0.539               4    5     0
# 4       0.1000       0.0318  107.993    0.525               4    7     0
# ...        ...          ...      ...      ...             ...  ...   ...
# 3894    0.1100       0.0575  115.924    0.585               4    0     0
# 3895    0.1250       0.0871   76.774    0.505               3    4     0
# 3896    0.0856       0.0414  122.004    0.061               4    0     0
# 3897    0.1020       0.0569  182.051    0.658               4    6     1
# 3898    0.1620       0.0455  118.989    0.384               4    5     1
#
#       release_year top_year  user
# 0             1996        0     0
# 1             2018     2022     1
# 2             2019     2020     2
# 3             2018     2018     2
# 4             2016     2020     3
# ...            ...      ...   ...
# 3894          1962     2020     5
# 3895          2019     2020     1
# 3896          2017     2021     4
# 3897          2017     2018     5
# 3898          2022        0     0
#
# [3890 rows x 15 columns]

# %%
mixed_playlist['user'].value_counts().get(0)
# Out:
# 100

# %%
# Extracting rows where 'user' is 0 into a new DataFrame
unknown_df = mixed_playlist[mixed_playlist['user'] == 0]

# Removing these rows from the original mixed_playlist DataFrame
mixed_playlist = mixed_playlist[mixed_playlist['user'] != 0]

# Displaying the first few rows of each DataFrame to confirm the operation
unknown_df_head = unknown_df.head()
mixed_playlist_head = mixed_playlist.head()

# %%
unknown_df_head
# Out:
#       length  popularity  acousticness  danceability  instrumentalness  \
# 0      76933          53         0.996         0.329             0.866
# 75    183773          22         0.994         0.629             0.947
# 80    551666          20         0.981         0.208             0.919
# 92    321146          26         0.870         0.258             0.898
# 150  1009706          27         0.913         0.502             0.857
#
#      liveness  speechiness    tempo  valence  time_signature  key  mode  \
# 0      0.0906       0.0448   70.295   0.2380               4   11     0
# 75     0.0864       0.0406  111.454   0.2410               4    0     0
# 80     0.0843       0.0342   62.543   0.0420               4    4     1
# 92     0.1480       0.0381   98.874   0.0378               4    5     0
# 150    0.0914       0.0473  105.740   0.5590               4    7     0
#
#      release_year top_year  user
# 0            1996        0     0
# 75           2018        0     0
# 80           1998        0     0
# 92           2019        0     0
# 150          1992        0     0

# %%
# # Feauture Scaling
# scaler = MinMaxScaler()
# mixed_playlist_scaled = scaler.fit_transform(mixed_playlist)
# mixed_playlist = pd.DataFrame(mixed_playlist_scaled, columns=mixed_playlist.columns)
# mixed_playlist
# Out:
#         length  popularity  acousticness  danceability  instrumentalness  \
# 0     0.024267    0.582418      1.000000      0.338826          0.870352
# 1     0.074881    0.681319      0.624497      0.633368          0.000008
# 2     0.076279    0.791209      0.414658      0.858908          0.000040
# 3     0.076278    0.000000      0.405622      0.820803          0.000154
# 4     0.123600    0.582418      0.061846      0.811535          0.714573
# ...        ...         ...           ...           ...               ...
# 3885  0.155017    0.450549      0.995984      0.544799          0.926633
# 3886  0.081694    0.000000      0.945783      0.429454          0.001709
# 3887  0.169812    0.560440      0.000015      0.480947          0.912563
# 3888  0.065467    0.175824      0.045481      0.606591          0.008523
# 3889  0.105030    0.362637      0.161645      0.745623          0.004462
#
#       liveness  speechiness     tempo   valence  time_signature       key  \
# 0     0.074710     0.047059  0.335383  0.242610             0.8  1.000000
# 1     0.178913     0.265756  0.414970  0.638124             0.8  0.090909
# 2     0.097729     0.358193  0.429345  0.362895             0.8  0.545455
# 3     0.243654     0.034349  0.610827  0.549439             0.8  0.454545
# 4     0.084370     0.033403  0.515244  0.535168             0.8  0.636364
# ...        ...          ...       ...       ...             ...       ...
# 3885  0.094646     0.060399  0.553083  0.596330             0.8  0.000000
# 3886  0.110061     0.091492  0.366295  0.514781             0.6  0.363636
# 3887  0.069571     0.043487  0.582091  0.062181             0.8  0.000000
# 3888  0.086425     0.059769  0.868581  0.670744             0.8  0.545455
# 3889  0.148083     0.047794  0.567706  0.391437             0.8  0.454545
#
#       mode  release_year  top_year      user
# 0      0.0      0.600000  0.000000  0.000000
# 1      1.0      0.938462  1.000000  0.166667
# 2      0.0      0.953846  0.999011  0.333333
# 3      0.0      0.938462  0.998022  0.333333
# 4      0.0      0.907692  0.999011  0.500000
# ...    ...           ...       ...       ...
# 3885   0.0      0.076923  0.999011  0.833333
# 3886   0.0      0.953846  0.999011  0.166667
# 3887   0.0      0.923077  0.999505  0.666667
# 3888   1.0      0.923077  0.998022  0.833333
# 3889   1.0      1.000000  0.000000  0.000000
#
# [3890 rows x 15 columns]

# %%
# K-Means clustering
X = mixed_playlist.values
model = KMeans(
    n_clusters = 6, # 6 clusters referred to 6 users 'delta': 1, 'gamma': 2, 'alpha': 3, 'dzeta': 4, 'beta': 5, 'epsilon': 6
    n_init = 'auto', # multiple attempt with different initial centroids
    random_state = 1, # fix ramdom state to guarantee reproducibility
    verbose = 1 # output log
)
model.fit(X)
# Out:
# Initialization complete
# Iteration 0, inertia 3265.7445493617574.
# Iteration 1, inertia 2317.2999583976016.
# Iteration 2, inertia 2224.743561332685.
# Iteration 3, inertia 2173.0526063718257.
# Iteration 4, inertia 2150.3130571052707.
# Iteration 5, inertia 2140.4745601340096.
# Iteration 6, inertia 2135.5147457575576.
# Iteration 7, inertia 2131.9030368468575.
# Iteration 8, inertia 2129.755640896196.
# Iteration 9, inertia 2127.7029148495662.
# Iteration 10, inertia 2125.324231946084.
# Iteration 11, inertia 2123.155279879134.
# Iteration 12, inertia 2119.311176100692.
# Iteration 13, inertia 2111.676113225555.
# Iteration 14, inertia 2103.895951510157.
# Iteration 15, inertia 2094.537046509772.
# Iteration 16, inertia 2087.5700518286258.
# Iteration 17, inertia 2084.0949590367422.
# Iteration 18, inertia 2082.649917700795.
# Iteration 19, inertia 2082.0990387620677.
# Iteration 20, inertia 2082.0139785181586.
# Iteration 21, inertia 2081.9986325135046.
# Iteration 22, inertia 2081.9926300333095.
# Converged at iteration 22: strict convergence.
# KMeans(n_clusters=6, n_init='auto', random_state=1, verbose=1)

# %%
# obtain the cluster centers
model.cluster_centers_
# Out:
# array([[ 1.24691984e-01,  2.80229205e-01,  4.92879904e-01,
#          4.68404661e-01,  8.44183180e-01,  1.38046381e-01,
#          5.70203382e-02,  5.37977464e-01,  2.43086744e-01,
#          7.61234991e-01,  4.54545455e-01,  1.00000000e+00,
#          8.60878744e-01,  9.50781540e-01,  6.28359062e-01],
#        [ 1.07171004e-01,  3.69287214e-01,  7.13417008e-01,
#          5.60597620e-01,  4.85461232e-02,  1.54754386e-01,
#          9.35371340e-02,  5.57134842e-01,  4.06326463e-01,
#          7.57945425e-01,  4.80373559e-01,  4.99600361e-16,
#          8.29213483e-01,  9.55309413e-01,  3.42964152e-01],
#        [ 1.03506931e-01,  3.73385738e-01,  1.44747904e-01,
#          6.78237375e-01,  6.86187429e-02,  1.69240651e-01,
#          1.20925724e-01,  5.70199522e-01,  5.38350434e-01,
#          7.97080292e-01,  5.68458306e-01, -4.44089210e-16,
#          8.93542953e-01,  9.97329257e-01,  6.17396594e-01],
#        [ 1.14593585e-01,  3.28877068e-01,  7.68805272e-01,
#          5.33351044e-01,  4.83792502e-02,  1.48054208e-01,
#          7.26460329e-02,  5.19994111e-01,  3.29219502e-01,
#          7.65605096e-01,  4.36402239e-01,  1.00000000e+00,
#          8.11073003e-01,  9.72935711e-01,  5.04600142e-01],
#        [ 1.27516968e-01,  3.13405196e-01,  5.28056072e-01,
#          4.51189585e-01,  8.40092354e-01,  1.28255314e-01,
#          5.43690131e-02,  5.49438475e-01,  2.19203337e-01,
#          7.58346582e-01,  5.09755745e-01,  4.99600361e-16,
#          8.62101015e-01,  9.52801379e-01,  6.55537891e-01],
#        [ 1.05348848e-01,  4.14366473e-01,  1.51327146e-01,
#          6.64906434e-01,  3.96554167e-02,  1.70806506e-01,
#          1.16430805e-01,  5.63946023e-01,  5.18248827e-01,
#          7.93963255e-01,  4.13385827e-01,  1.00000000e+00,
#          8.64889966e-01,  9.94542967e-01,  5.76334208e-01]])

# %%
cluster_centers = pd.DataFrame(
    model.cluster_centers_,
    columns = mixed_playlist.columns
)
cluster_centers
# Out:
#      length  popularity  acousticness  danceability  instrumentalness  \
# 0  0.124692    0.280229      0.492880      0.468405          0.844183
# 1  0.107171    0.369287      0.713417      0.560598          0.048546
# 2  0.103507    0.373386      0.144748      0.678237          0.068619
# 3  0.114594    0.328877      0.768805      0.533351          0.048379
# 4  0.127517    0.313405      0.528056      0.451190          0.840092
# 5  0.105349    0.414366      0.151327      0.664906          0.039655
#
#    liveness  speechiness     tempo   valence  time_signature       key  \
# 0  0.138046     0.057020  0.537977  0.243087        0.761235  0.454545
# 1  0.154754     0.093537  0.557135  0.406326        0.757945  0.480374
# 2  0.169241     0.120926  0.570200  0.538350        0.797080  0.568458
# 3  0.148054     0.072646  0.519994  0.329220        0.765605  0.436402
# 4  0.128255     0.054369  0.549438  0.219203        0.758347  0.509756
# 5  0.170807     0.116431  0.563946  0.518249        0.793963  0.413386
#
#            mode  release_year  top_year      user
# 0  1.000000e+00      0.860879  0.950782  0.628359
# 1  4.996004e-16      0.829213  0.955309  0.342964
# 2 -4.440892e-16      0.893543  0.997329  0.617397
# 3  1.000000e+00      0.811073  0.972936  0.504600
# 4  4.996004e-16      0.862101  0.952801  0.655538
# 5  1.000000e+00      0.864890  0.994543  0.576334

# %%
mixed_playlist
# Out:
#         length  popularity  acousticness  danceability  instrumentalness  \
# 0     0.024267    0.582418      1.000000      0.338826          0.870352
# 1     0.074881    0.681319      0.624497      0.633368          0.000008
# 2     0.076279    0.791209      0.414658      0.858908          0.000040
# 3     0.076278    0.000000      0.405622      0.820803          0.000154
# 4     0.123600    0.582418      0.061846      0.811535          0.714573
# ...        ...         ...           ...           ...               ...
# 3885  0.155017    0.450549      0.995984      0.544799          0.926633
# 3886  0.081694    0.000000      0.945783      0.429454          0.001709
# 3887  0.169812    0.560440      0.000015      0.480947          0.912563
# 3888  0.065467    0.175824      0.045481      0.606591          0.008523
# 3889  0.105030    0.362637      0.161645      0.745623          0.004462
#
#       liveness  speechiness     tempo   valence  time_signature       key  \
# 0     0.074710     0.047059  0.335383  0.242610             0.8  1.000000
# 1     0.178913     0.265756  0.414970  0.638124             0.8  0.090909
# 2     0.097729     0.358193  0.429345  0.362895             0.8  0.545455
# 3     0.243654     0.034349  0.610827  0.549439             0.8  0.454545
# 4     0.084370     0.033403  0.515244  0.535168             0.8  0.636364
# ...        ...          ...       ...       ...             ...       ...
# 3885  0.094646     0.060399  0.553083  0.596330             0.8  0.000000
# 3886  0.110061     0.091492  0.366295  0.514781             0.6  0.363636
# 3887  0.069571     0.043487  0.582091  0.062181             0.8  0.000000
# 3888  0.086425     0.059769  0.868581  0.670744             0.8  0.545455
# 3889  0.148083     0.047794  0.567706  0.391437             0.8  0.454545
#
#       mode  release_year  top_year      user
# 0      0.0      0.600000  0.000000  0.000000
# 1      1.0      0.938462  1.000000  0.166667
# 2      0.0      0.953846  0.999011  0.333333
# 3      0.0      0.938462  0.998022  0.333333
# 4      0.0      0.907692  0.999011  0.500000
# ...    ...           ...       ...       ...
# 3885   0.0      0.076923  0.999011  0.833333
# 3886   0.0      0.953846  0.999011  0.166667
# 3887   0.0      0.923077  0.999505  0.666667
# 3888   1.0      0.923077  0.998022  0.833333
# 3889   1.0      1.000000  0.000000  0.000000
#
# [3890 rows x 15 columns]

# %%
# Initialize an empty list to store predictions
predictions = []
# Loop through each row in the DataFrame
for n in range(len(mixed_playlist)):
    # Access the nth row and reshape it to a 2D array
    row_data = mixed_playlist.loc[n].values.reshape(1, -1)
    # Get the prediction and append it to the list
    prediction = model.predict(row_data)
    predictions.append(prediction[0])  # Assuming 'predict' returns a list or array
# Convert the list of predictions to a DataFrame
predictions_df = pd.DataFrame(predictions, columns=['Prediction'])
# Now 'predictions_df' is a DataFrame with all predictions
print(predictions_df)

mixed_playlist
# Out:
#       Prediction
# 0              4
# 1              3
# 2              1
# 3              2
# 4              2
# ...          ...
# 3885           4
# 3886           1
# 3887           4
# 3888           5
# 3889           5
#
# [3890 rows x 1 columns]
#         length  popularity  acousticness  danceability  instrumentalness  \
# 0     0.024267    0.582418      1.000000      0.338826          0.870352
# 1     0.074881    0.681319      0.624497      0.633368          0.000008
# 2     0.076279    0.791209      0.414658      0.858908          0.000040
# 3     0.076278    0.000000      0.405622      0.820803          0.000154
# 4     0.123600    0.582418      0.061846      0.811535          0.714573
# ...        ...         ...           ...           ...               ...
# 3885  0.155017    0.450549      0.995984      0.544799          0.926633
# 3886  0.081694    0.000000      0.945783      0.429454          0.001709
# 3887  0.169812    0.560440      0.000015      0.480947          0.912563
# 3888  0.065467    0.175824      0.045481      0.606591          0.008523
# 3889  0.105030    0.362637      0.161645      0.745623          0.004462
#
#       liveness  speechiness     tempo   valence  time_signature       key  \
# 0     0.074710     0.047059  0.335383  0.242610             0.8  1.000000
# 1     0.178913     0.265756  0.414970  0.638124             0.8  0.090909
# 2     0.097729     0.358193  0.429345  0.362895             0.8  0.545455
# 3     0.243654     0.034349  0.610827  0.549439             0.8  0.454545
# 4     0.084370     0.033403  0.515244  0.535168             0.8  0.636364
# ...        ...          ...       ...       ...             ...       ...
# 3885  0.094646     0.060399  0.553083  0.596330             0.8  0.000000
# 3886  0.110061     0.091492  0.366295  0.514781             0.6  0.363636
# 3887  0.069571     0.043487  0.582091  0.062181             0.8  0.000000
# 3888  0.086425     0.059769  0.868581  0.670744             0.8  0.545455
# 3889  0.148083     0.047794  0.567706  0.391437             0.8  0.454545
#
#       mode  release_year  top_year      user
# 0      0.0      0.600000  0.000000  0.000000
# 1      1.0      0.938462  1.000000  0.166667
# 2      0.0      0.953846  0.999011  0.333333
# 3      0.0      0.938462  0.998022  0.333333
# 4      0.0      0.907692  0.999011  0.500000
# ...    ...           ...       ...       ...
# 3885   0.0      0.076923  0.999011  0.833333
# 3886   0.0      0.953846  0.999011  0.166667
# 3887   0.0      0.923077  0.999505  0.666667
# 3888   1.0      0.923077  0.998022  0.833333
# 3889   1.0      1.000000  0.000000  0.000000
#
# [3890 rows x 15 columns]

# %%
# mixed_playlist = scaler.inverse_transform(mixed_playlist)

# mixed_playlist_df = pd.DataFrame(mixed_playlist)

# mixed_playlist_df
