# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = r'C:\Users\CristianMedina\Desktop\ML\data\mixed_playlist.csv'
mixed_playlist = pd.read_csv(file_path)

# %%
# mixed_playlist.head(10)
num_categories = mixed_playlist.user.unique()
mapping = {'unknown': 0, 'delta': 1, 'gamma': 2, 'alpha': 3, 'dzeta': 4, 'beta': 5, 'epsilon': 6}
mixed_playlist['user'] = mixed_playlist['user'].replace(mapping)
mixed_playlist.user
# Out:
# 0       0
# 1       1
# 2       2
# 3       2
# 4       3
#        ..
# 3894    5
# 3895    1
# 3896    4
# 3897    5
# 3898    0
# Name: user, Length: 3899, dtype: int64

# %%
# Replace 'unknown' values in 'top_year' column with 0
mixed_playlist['top_year'] = mixed_playlist['top_year'].replace('unknown', 0)
mixed_playlist.top_year
# Out:
# 0          0
# 1       2022
# 2       2020
# 3       2018
# 4       2020
#         ...
# 3894    2020
# 3895    2020
# 3896    2021
# 3897    2018
# 3898       0
# Name: top_year, Length: 3899, dtype: object

# %%
unknown_df_user = mixed_playlist[(mixed_playlist['user'] == 0)]
unknown_df_user
# Out:
#                                                    name  \
# 0     Variations on a Polish Theme, Op. 10: No. 5 An...
# 75                                          For Jóhann
# 80    Concerto For Piano And Orchestra In G, Second ...
# 92                       This Reminds You - Satie Remix
# 150                                           Sull Lull
# ...                                                 ...
# 3645                                     Como Siento Yo
# 3725            Tristezas De Um Violão - 2003 Remaster
# 3761  6 Stucke, Op. 32: 6 Pieces, Op. 32: No. 3. Rus...
# 3802                                              Pause
# 3898                           Sea, Sex And Sun - Remix
#
#                                     album               artist release_date  \
# 0        Szymanowski: Piano Works, Vol. 2    Karol Szymanowski   06/12/1996
# 75                   Bach Reworks (Pt. 1)  Víkingur Ólafsson   05/10/2018
# ...

# %%
unknown_df_year = mixed_playlist[(mixed_playlist['top_year'] == 0)]
unknown_df_year
# Out:
#                                                    name  \
# 0     Variations on a Polish Theme, Op. 10: No. 5 An...
# 75                                          For Jóhann
# 80    Concerto For Piano And Orchestra In G, Second ...
# 92                       This Reminds You - Satie Remix
# 150                                           Sull Lull
# ...                                                 ...
# 3645                                     Como Siento Yo
# 3725            Tristezas De Um Violão - 2003 Remaster
# 3761  6 Stucke, Op. 32: 6 Pieces, Op. 32: No. 3. Rus...
# 3802                                              Pause
# 3898                           Sea, Sex And Sun - Remix
#
#                                     album               artist release_date  \
# 0        Szymanowski: Piano Works, Vol. 2    Karol Szymanowski   06/12/1996
# 75                   Bach Reworks (Pt. 1)  Víkingur Ólafsson   05/10/2018
# ...

# %%
#Checking the 0 values in user and top_year
unknown_df_user_year = mixed_playlist[(mixed_playlist['user'] == 0) & (mixed_playlist['top_year'] == 0)]
unknown_df_user_year
# Out:
#                                                    name  \
# 0     Variations on a Polish Theme, Op. 10: No. 5 An...
# 75                                          For Jóhann
# 80    Concerto For Piano And Orchestra In G, Second ...
# 92                       This Reminds You - Satie Remix
# 150                                           Sull Lull
# ...                                                 ...
# 3645                                     Como Siento Yo
# 3725            Tristezas De Um Violão - 2003 Remaster
# 3761  6 Stucke, Op. 32: 6 Pieces, Op. 32: No. 3. Rus...
# 3802                                              Pause
# 3898                           Sea, Sex And Sun - Remix
#
#                                     album               artist release_date  \
# 0        Szymanowski: Piano Works, Vol. 2    Karol Szymanowski   06/12/1996
# 75                   Bach Reworks (Pt. 1)  Víkingur Ólafsson   05/10/2018
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('data/recovered_data/user_alpha/user_alpha_2016.csv')
# df
# df['top_year'].value_counts().get(0)
# df['user'].value_counts().get('alpha')
# Out:
#    name album artist release_date length popularity acousticness danceability  \
# 0   NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 1   NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 2   NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 3   NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 4   NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# ..  ...   ...    ...          ...    ...        ...          ...          ...
# 95  NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 96  NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 97  NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 98  NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
# 99  NaN   NaN    NaN          NaN    NaN        NaN          NaN          NaN
#
# ...
